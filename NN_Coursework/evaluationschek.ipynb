# %%
import matplotlib.pyplot as plt
import operator

# %%
plt.rcParams["figure.figsize"] = (6,6)
plt.title("Измерения BLEU")

y_bleu_vgg16 = [0.547214, 0.574484, 0.569651, 0.562040, 0.574687,
                0.580390, 0.586214, 0.567054, 0.548946, 0.524117,
                0.517806, 0.510654, 0.526720, 0.523348, 0.502979,
                0.415937, 0.495484, 0.431496, 0.576722, 0.546610]

y_bleu_inception = [0.506083, 0.578135, 0.584309, 0.578745, 0.575544,
                    0.571140, 0.563990, 0.520316, 0.543916, 0.570103,
                    0.572328, 0.559946, 0.572345, 0.571155, 0.569178,
                    0.571094, 0.559461, 0.535523, 0.584450, 0.558483]

x_epochs = range(1, 21)
plt.plot(x_epochs, y_bleu_vgg16, "red", label="VGG16")
plt.plot(x_epochs, y_bleu_inception, "blue", label="Inception")

plt.legend()
plt.show()

# %%
index, value = max(enumerate(y_bleu_vgg16), key=operator.itemgetter(1))
index +=1
print("VGG16 ....... эпоха ... " + str(index) + " ... максимальное измерение BLUE ... " + str(value))

index, value = max(enumerate(y_bleu_inception), key=operator.itemgetter(1))
index +=1
print("Inception ... эпоха ... " + str(index) + " ... максимальное измерение BLUE ... " + str(value))
# Out:
# VGG16 ....... эпоха ... 7 ... максимальное измерение BLUE ... 0.586214
# Inception ... эпоха ... 19 ... максимальное измерение BLUE ... 0.58445
